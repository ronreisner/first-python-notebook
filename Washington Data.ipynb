# %%
import pandas as pd

# %%
# props = pd.read_csv("test.cvs")

# %%
# contribs = pd.read_csv("Data_that_works.cvs")

# %%
contribs = pd.read_csv("C:\Users\Ron_2\Downloads\Campaign_Finance_Reporting_History.cvs")
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-25-3d7a781b9b37> in <module>()
# ----> 1 contribs = pd.read_csv("C:\Users\Ron_2\Downloads\Campaign_Finance_Reporting_History.cvs")
#
# c:\code\first-python-notebook\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
#contribs = pd.read_csv("Copied_data.cvs")

# %%
# contribs = pd.read_csv("C://Data//Copied_data.cvs")

# %%
contribs.head()
# Out:
#    report_number  amends_report  amended_by_report origin    filer_id  \
# 0      100115384            NaN                NaN     C3  PRIDC  661
# 1      100308648            NaN                NaN     C1  WOLFW  403
# 2      100308656            NaN                NaN     C1  ROSED  352
# 3      100308667            NaN                NaN     C1  ISAAR  801
# 4      100308677            NaN                NaN     C1  CAMMJ  363
#
#    election_year       type              filer_name first_name middle_initial  \
# 0           2008  Candidate       PRIDEMORE CRAIG A      CRAIG              A
# 1           2009  Candidate  WOLFINBARGER WILLIAM R    WILLIAM              R
# 2           2009  Candidate            ROSE DAVID W      DAVID              W
# 3           2009  Candidate      ISAACSON RICHARD M    RICHARD              M
# 4           2009  Candidate         CAMMACK JAMES G      JAMES              G
#
#   ...  ballot_number for_or_against               jurisdiction  \
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477259 entries, 0 to 477258
# Data columns (total 25 columns):
# report_number           477259 non-null int64
# amends_report           49669 non-null float64
# amended_by_report       49680 non-null float64
# origin                  477259 non-null object
# filer_id                477259 non-null object
# election_year           477259 non-null int64
# type                    477259 non-null object
# filer_name              477259 non-null object
# first_name              272939 non-null object
# middle_initial          245289 non-null object
# last_name               477253 non-null object
# office                  272944 non-null object
# legislative_district    101156 non-null float64
# position                193587 non-null object
# party                   272824 non-null object
# ballot_number           11442 non-null float64
# for_or_against          32579 non-null object
# jurisdiction            284325 non-null object
# ...

# %%
contribs.last_name.value_counts().reset_index()
# Out:
#                                           index  last_name
# 0               WA ST DEMO CENT COMM NON EXEMPT       5009
# 1          WHATCOM CO DEMO CENT COMM NON EXEMPT       2218
# 2         THURSTON CO DEMO CENT COMM NON EXEMPT       1923
# 3                                       JOHNSON       1800
# 4                         WA EDUCATION ASSN PAC       1656
# 5          SPOKANE CO DEMO CENT COMM NON EXEMPT       1569
# 6            CLARK CO DEMO CENT COMM NON EXEMPT       1464
# 7             KING CO DEMO CENT COMM NON EXEMPT       1431
# 8     JEFFERSON CO DEMOS & CENT COMM NON EXEMPT       1328
# 9                                         SMITH       1317
# 10                                      MCKENNA       1293
# 11                                     GREGOIRE       1265
# 12          SKAGIT CO DEMO CENT COMM NON EXEMPT       1252
# 13                                         DUNN       1234
# 14            WHATCOM CO REPUB PARTY NON EXEMPT       1222
# ...

# %%
contribs.describe
# Out:
# <bound method DataFrame.describe of         report_number  amends_report  amended_by_report origin    filer_id  \
# 0           100115384            NaN                NaN     C3  PRIDC  661
# 1           100308648            NaN                NaN     C1  WOLFW  403
# 2           100308656            NaN                NaN     C1  ROSED  352
# 3           100308667            NaN                NaN     C1  ISAAR  801
# 4           100308677            NaN                NaN     C1  CAMMJ  363
# 5           100308678            NaN                NaN     C1  LESKJ  362
# 6           100308685            NaN                NaN     C1  MCDAT  626
# 7           100308690            NaN                NaN     C1  WEBED  632
# 8           100308694            NaN                NaN     C1  HARTJ  626
# 9           100308723            NaN                NaN     C1  LAWRD  520
# 10          100308759            NaN                NaN     C1  GEHRR  038
# ...
